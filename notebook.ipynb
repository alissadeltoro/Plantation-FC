# %% [markdown]
# ![alvaro-mendoza-6dRiUBjRvsM-unsplash](alvaro-mendoza-6dRiUBjRvsM-unsplash.jpg)
#
# # PFC School Pick Likelihood: Top Programs for Rising Freshman Soccer Players
# In supporting Plantation Football Club UPSL players in college preparation, this project is aggregating player data (including performance and academics) and comparing that against the dream, target, and safety schools the player's have indicated on a survey (distributed internally). This project will be conducted in phases with the end goal of providing the top 3 best fit schools (i.e. Junior College, Division 1 - 3), based on aformentioned data sources. Thereafter, this project will be used to spit out insights reports for the team for use in future seasons to improve player management and demonstrate the benefits of PFC UPSL and how it acts as a jump off point to leveling up a player's soccer career.
#
# _PHASE 0: Identifying base key metrics to be acquired from players and schools used by scouts to determine interest_
# _PHASE 1: Data capture of player information via survey to club members (UPSL U19s and U17s)_
# Building data pipelines from NCAA, NJCAA, and "interested" school websites. (Using an ETL process)
# 1. Data Wrangling: Website URLs to pull statistics from, additional data to be captured in-house
# - Seperated the files by statistic due to issues with parsing a full csv
# - Next step is to go back and do it from the larger csv where I splice it without issue
# - Detailed statistics can be found here: http://web1.ncaa.org/stats/StatsSrv/rankings
# 3. Data Cleaning: Transforming data into appropriate fields, types, etc. for analysis
# 4. Data Storing: Create files to be used in python for future phases and model building
#
# TO-DOs:
# - Clean up school tables (e.g. name column to match)
# - Get academic information for each of the relevant schools
# - Pull in dummy player information from UPSL spreadsheet for time being
# - Update with actuals once available
# - Create a fuzzy match as a catch all for spelling character mistakes
#
# PHASE 2: Explore the data and determine key data to pull into one table for players and one table for teams
# - Data exploration using SQL and the df created in Python in Phase 1
# - Formulate foundational insights from school data (e.g. graduating seniors in position, GPA, major)
#
# PHASE 3: Weight information against acceptance rates as a soccer player & stats matching for similar player profile on team
# PHASE 4: Adjust and update accordingly to improve accuracy of model (incl. historical training data)
# PHASE 5: Automate data capture to pull in total teams in all leagues & run player profile against model to find best fit

# %% [markdown]
# ## PHASE 1: DATA GATHERING

# %%
import pandas as pd

# %%
# NCAA Mens Soccer RPI Rankings 2023
url_ncaa_d1_teams = "https://www.ncaa.com/rankings/soccer-men/d1/ncaa-mens-soccer-rpi"

html_ncaa_d1_teams = pd.read_html(url_ncaa_d1_teams)

# %%
html_ncaa_d1_teams[0].head()
# Out:
#    Rank      School Conference  Record   Road Neutral    Home Non Div I
# 0     1    Syracuse        ACC  19-2-4  5-0-2   3-0-0  11-2-2     0-0-0
# 1     2     Indiana    Big Ten  13-5-6  4-3-3   1-1-0   8-1-3     1-0-0
# 2     3   Creighton   Big East  13-5-6  5-3-2   2-1-0   6-1-4     0-0-0
# 3     4    Virginia        ACC  10-4-5  3-0-2   0-1-0   7-3-3     0-0-0
# 4     5  Washington     Pac-12  15-2-3  5-0-2   0-0-0  10-2-1     0-0-0

# %%
rankings_ncaa_d1_teams = html_ncaa_d1_teams[0]

# %%
rankings_ncaa_d1_teams.dtypes
# Out:
# Rank           int64
# School        object
# Conference    object
# Record        object
# Road          object
# Neutral       object
# Home          object
# Non Div I     object
# dtype: object

# %%
rankings_ncaa_d1_teams[['Wins', 'Draws', 'Loses']] = rankings_ncaa_d1_teams['Record'].str.split('-', expand=True)

print(rankings_ncaa_d1_teams.head())
# Out:
#    Rank      School Conference  Record  ... Non Div I Wins Draws Loses
# 0     1    Syracuse        ACC  19-2-4  ...     0-0-0   19     2     4
# 1     2     Indiana    Big Ten  13-5-6  ...     1-0-0   13     5     6
# 2     3   Creighton   Big East  13-5-6  ...     0-0-0   13     5     6
# 3     4    Virginia        ACC  10-4-5  ...     0-0-0   10     4     5
# 4     5  Washington     Pac-12  15-2-3  ...     0-0-0   15     2     3
#
# [5 rows x 11 columns]

# %%
# FIU Website Team Stats 
url_fiu = "https://fiusports.com/sports/mens-soccer/stats/2023"

html_fiu = pd.read_html(url_fiu)

# %%
len(html_fiu)
# Out:
# 24

# %%
#TO DO: Clean up Player Name to "FirstName LastName"
html_fiu[1].head()
# Out:
#       #                                             Player  ...  PG-PA  Bio Link
# 0   9.0                  Mustre, Eduardo  9Mustre, Eduardo  ...    1-1  View Bio
# 1   4.0                    Skraep, Kasper  4Skraep, Kasper  ...    0-0  View Bio
# 2  10.0                       Nagao, Yushi  10Nagao, Yushi  ...    0-0  View Bio
# 3  20.0                        Alves, Paulo 20Alves, Paulo  ...    0-0  View Bio
# 4   7.0  Dos Santos Monteiro, Bernardo  7Dos Santos Mon...  ...    0-0  View Bio
#
# [5 rows x 16 columns]

# %%
#TO DO: Clean up Player Name to "FirstName LastName"
html_fiu[2].head()
# Out:
#       #                                          Player  ...  SF  Bio Link
# 0  30.0                    Hogan, Tyler  30Hogan, Tyler  ...  38  View Bio
# 1  28.0  Sigurjonsson, Vilhelm  28Sigurjonsson, Vilhelm  ...  13  View Bio
# 2   NaN                                           Total  ...  51       NaN
# 3   NaN                                       Opponents  ...  93       NaN
#
# [4 rows x 15 columns]

# %%
html_fiu[0].head()
# Out:
#                 Statistic No. 11 FIU Opponents  OPP
# 0                   Shots      Shots          Shots
# 1                Goals  G          9              7
# 2   Goals Per Game  G/AVG       1.50           1.17
# 3               Shots  SH         93             51
# 4  Shots Per Game  SH/AVG       15.5            8.5

# %%
# Total Team Stats Tables - FIU
team_fiu = html_fiu[0]
off_fiu = html_fiu[1]
gk_fiu = html_fiu[2]

# %%
# NCAA D1 Stats - Player Details
# Note: Come back and create a function to parse all files going forward and generate tables
table_ncaa_d1_apg = pd.read_csv("2223_NCAA D1_Assist Per Game.csv", header=3)
table_ncaa_d1_glsagt = pd.read_csv("2223_NCAA D1_Goals Against Avg.csv", header=3)
table_ncaa_d1_gpg = pd.read_csv("2223_NCAA D1_Goals Per Game.csv", header=3)
table_ncaa_d1_spg = pd.read_csv("2223_NCAA D1_Saves Per Game.csv", header=3)
table_ncaa_d1_ttla = pd.read_csv("2223_NCAA D1_Total Assists.csv", header=3, encoding='latin-1')

# %%
table_ncaa_d1_apg.head()
# Out:
#   Rank                Name               Team  ... Games Assists  Per Game
# 0    1        Nick Gutmann           Kentucky  ...  21.0    19.0      0.90
# 1    2         Tom Cooklin  George Washington  ...  17.0    13.0      0.76
# 2    3      Willem Ebbinge            Harvard  ...  16.0    11.0      0.69
# 3    4           JC Ngando     UNC Greensboro  ...  21.0    14.0      0.67
# 4    5  Alexander Petraeus                SMU  ...  16.0    10.0      0.63
#
# [5 rows x 8 columns]

# %%
table_ncaa_d1_glsagt.head()
# Out:
#   Rank                Name           Team  ... Goalie Min. Plyd    GA    GAA
# 0    1        Hunter Morse  Western Mich.  ...          1907:57  10.0  0.472
# 1    2       Danny DiMarco      Manhattan  ...          1200:48   7.0  0.525
# 2    3        Eliot Hamill           Duke  ...          1710:00  11.0  0.579
# 3    4  Lute Lillo Portero          Omaha  ...           765:00   5.0  0.588
# 4    5     Jassem Koleilat  New Hampshire  ...          1802:58  12.0  0.599
#
# [5 rows x 9 columns]

# %%
table_ncaa_d1_gpg.head()
# Out:
#   Rank               Name          Team   Cl Pos  Games  Goals  Per Game
# 0    1     Duncan McGuire     Creighton  Jr.   F   24.0   23.0      0.96
# 1    2      Lucca Dourado           UCF  Jr.   F   13.0   11.0      0.85
# 2    3    Eliot Goldthorp       Hofstra  So.   M   21.0   17.0      0.81
# 3    4  Emil Jaaskelainen           LIU  Jr.   F   15.0   12.0      0.80
# 4    5        Shaun Joash  Grand Canyon  Sr.   F   16.0   12.0      0.75

# %%
table_ncaa_d1_spg.head()
# Out:
#   Rank             Name          Team  ... Goalie Min. Plyd Saves  Per Game
# 0    1     Rotem Fadida      Hartford  ...          1022:54  78.0      6.50
# 1    2  Michael Sly Jr.       Oakland  ...          1458:36  98.0      5.76
# 2    3   Luca Marinelli        Bryant  ...          1080:00  69.0      5.75
# 3    4    Jacob Heihsel  UMass Lowell  ...          1080:00  68.0      5.67
# 4    5     Gabe Calhoun           VMI  ...          1350:00  84.0      5.60
#
# [5 rows x 9 columns]

# %%
table_ncaa_d1_ttla.head()
# Out:
#   Rank                    Name               Team   Cl Pos  Games  Assists
# 0    1            Nick Gutmann           Kentucky  Sr.   M   21.0     19.0
# 1    2               JC Ngando     UNC Greensboro  So.   M   21.0     14.0
# 2  NaN           Giorgio Probo          Creighton  So.   M   24.0     14.0
# 3    4             Tom Cooklin  George Washington  Sr.   F   17.0     13.0
# 4  NaN  Alexander Stjernegaard         Quinnipiac  Fr.   D   21.0     13.0

# %%
# UPSL Plantation FC Division 1 and 2 Team Details + Player Stats
import requests

# Team Standings
url_upsl_prem = requests.get("https://premier.upsl.com/standings/").content
url_upsl_div = requests.get("https://division1.upsl.com/standings/").content

html_upsl_prem = pd.read_html(url_upsl_prem)
html_upsl_div = pd.read_html(url_upsl_div)

# %%
len(html_upsl_prem)
# Out:
# 26

# %%
len(html_upsl_div)
# Out:
# 21

# %%
# Premiere League: Plantation FC
html_upsl_prem[6]
# Out:
#      P                     Team  GP  W  D  ...   Latest  GF  GA  GD  PTSP
# 0    1          Little Haiti FC   4  4  0  ...  W W W W  18   5  13    12
# 1    2            Plantation FC   2  2  0  ...      W W   7   2   5     6
# 2    3   Inter Miami CF Academy   2  2  0  ...      W W   6   2   4     6
# 3    4                      ISA   3  2  0  ...    W W L   6   5   1     6
# 4    5    Athletum Miami FC U19   3  2  0  ...    W L W   6   6   0     6
# 5    6           Dade County FC   3  1  1  ...    W D L   7   5   2     4
# 6    7           City Soccer FC   4  1  1  ...  D W L L   5  11  -6     4
# 7    8      Rush Select Academy   1  1  0  ...        W   4   2   2     3
# 8    9          Hodler Miami Fc   3  1  0  ...    L W L   6   5   1     3
# 9   10     Parkland Soccer Club   2  1  0  ...      L W   3   3   0     3
# 10  11                Weston FC   2  0  0  ...      L L   1   4  -3     0
# 11  12     Palm Beach Flames SC   2  0  0  ...      L L   3   7  -4     0
# 12  13  Florida Soccer Soldiers   2  0  0  ...      L L   5  10  -5     0
# 13  14    Miami Rush Kendall SC   3  0  0  ...    L L L   1  11 -10     0
#
# [14 rows x 13 columns]

# %%
# U19 League: Plantation FC II
html_upsl_div[7]
# Out:
#      P                               Team  GP  W  D  ...  Latest GF GA GD  PTSP
# 0    1                Weston FC U19 Black   1  1  0  ...       W  3  2  1     3
# 1    2                   Island United AC   1  1  0  ...       W  3  2  1     3
# 2    3                   Plantation FC II   1  0  1  ...       D  0  0  0     1
# 3    4     South Florida Football Academy   2  0  1  ...     D L  2  3 -1     1
# 4    5              Athletum Miami FC U17   0  0  0  ...     NaN  0  0  0     0
# 5    6                Springs Soccer Club   0  0  0  ...     NaN  0  0  0     0
# 6    7                  Milan De Miami FC   0  0  0  ...     NaN  0  0  0     0
# 7    8            Parkland Soccer Club II   0  0  0  ...     NaN  0  0  0     0
# 8    9  Atletico de Madrid Academia Miami   0  0  0  ...     NaN  0  0  0     0
# 9   10                          Empire SC   0  0  0  ...     NaN  0  0  0     0
# 10  11                Florida Futbol Club   0  0  0  ...     NaN  0  0  0     0
# 11  12                         JETSETV FC   1  0  0  ...       L  2  3 -1     0
#
# [12 rows x 13 columns]

# %%
# U17 League: Plantation FC III
html_upsl_div[8]
# Out:
#      P                               Team  GP  W  D  ...  Latest GF GA GD  PTSP
# 0    1                     Rush Select II   1  1  0  ...       W  4  1  3     3
# 1    2                Weston FC U18 Black   1  0  1  ...       D  2  2  0     1
# 2    3             Milan de Miami Academy   1  0  1  ...       D  2  2  0     1
# 3    4              Athletum FC U19 Elite   0  0  0  ...     NaN  0  0  0     0
# 4    5                 Hodler Miami FC II   0  0  0  ...     NaN  0  0  0     0
# 5    6  South Florida Football Academy II   0  0  0  ...     NaN  0  0  0     0
# 6    7                 Naples City FC D.1   0  0  0  ...     NaN  0  0  0     0
# 7    8                             FBS FC   0  0  0  ...     NaN  0  0  0     0
# 8    9                PSG Academy Florida   0  0  0  ...     NaN  0  0  0     0
# 9   10                  Plantation FC III   0  0  0  ...     NaN  0  0  0     0
# 10  11                         ISA Schulz   1  0  0  ...       L  1  4 -3     0
#
# [11 rows x 13 columns]

# %%
# Plantation FC: Individual Player & Game Details
url_upsl_pfcp = requests.get("https://premier.upsl.com/teams/plantation-fc-241834/").content
url_upsl_pfcd1 = requests.get("https://division1.upsl.com/teams/plantation-fc-ii-39664/").content
url_upsl_pfcd2 = requests.get("https://division1.upsl.com/teams/plantation-fc-iii-90727/").content

html_upsl_pfcp = pd.read_html(url_upsl_pfcp)
html_upsl_pfcd1 = pd.read_html(url_upsl_pfcd1)
html_upsl_pfcd2 = pd.read_html(url_upsl_pfcd2)

# %%
len(html_upsl_pfcp)
# Out:
# 1

# %%
html_upsl_pfcp[0]
# Out:
#                       Home  ...            Unnamed: 7
# 0            Plantation FC  ...  upsl__show__schedule
# 1            Plantation FC  ...   upsl__show__results
# 2          Hodler Miami Fc  ...   upsl__show__results
# 3            Plantation FC  ...  upsl__show__schedule
# 4     Palm Beach Flames SC  ...  upsl__show__schedule
# 5   Inter Miami CF Academy  ...  upsl__show__schedule
# 6            Plantation FC  ...  upsl__show__schedule
# 7            Plantation FC  ...  upsl__show__schedule
# 8            Plantation FC  ...   upsl__show__results
# 9     Parkland Soccer Club  ...  upsl__show__schedule
# 10           Plantation FC  ...  upsl__show__schedule
# 11           Plantation FC  ...  upsl__show__schedule
# 12           Plantation FC  ...  upsl__show__schedule
#
# [13 rows x 8 columns]

# %%
# UPSL PFC Player Questionnaire Responses

table_survey = pd.read_csv("UPSL College Prep - Responses_ Player Profile CV.csv")

# %%
table_survey.head()
# Out:
#             Timestamp  ... Club 1: Age Group.1
# 0  9/12/2023 18:44:30  ...                 NaN
#
# [1 rows x 63 columns]

# %% [markdown]
# ## PHASE 2: DATA EXPLORATION (IN SQL)

# %%
-- Query a variable:
-- SELECT * FROM df
--
-- Query a CSV file:
-- SELECT * FROM 'data.csv'

SELECT Pos, COUNT(*) FROM table_ncaa_d1_ttla WHERE Cl = 'Sr.' GROUP BY Pos
# Out:
#   Pos  count_star()
# 0   M            33
# 1   F            25
# 2   D            10

# %%
SELECT * FROM table_ncaa_d1_ttla WHERE Cl = 'Sr.' AND Pos = 'M'
# Out:
#    Rank                 Name            Team   Cl Pos  Games  Assists
# 0     1         Nick Gutmann        Kentucky  Sr.   M   21.0     19.0
# 1     9          Ryan Becher            UMBC  Sr.   M   18.0     10.0
# 2   NaN        Dylan Gaither          Mercer  Sr.   M   19.0     10.0
# 3   NaN        Stephen Hasse         Niagara  Sr.   M   20.0      9.0
# 4   NaN   Leopoldo Hernandez    UC Riverside  Sr.   M   20.0      9.0
# 5   NaN            Alex Nagy         Vermont  Sr.   M   17.0      9.0
# 6   NaN      Jacob Angeletti       Air Force  Sr.   M   17.0      8.0
# 7   NaN     Malcolm Johnston        Maryland  Sr.   M   17.0      8.0
# 8   NaN  Alexander Levengood  William & Mary  Sr.   M   18.0      8.0
# 9   NaN           Lucas Meek      Washington  Sr.   M   20.0      8.0
# 10  NaN      Brandon Morales         Cornell  Sr.   M   19.0      8.0
# 11  NaN      Nick Richardson        Maryland  Sr.   M   20.0      8.0
# 12  NaN        Charlie Sharp   Western Mich.  Sr.   M   21.0      8.0
# 13  NaN            Ben Stitz            Penn  Sr.   M   18.0      8.0
# 14  NaN       Jackson Temple         Rutgers  Sr.   M   21.0      8.0
# 15  NaN            Koby Carr       Charlotte  Sr.   M   14.0      7.0
# 16  NaN      Will Echeverria       Lafayette  Sr.   M   18.0      7.0
# 17  NaN          Billy Hency  Loyola Chicago  Sr.   M   18.0      7.0
# 18  NaN           Louis Sala    Michigan St.  Sr.   M   16.0      7.0
# 19  NaN           Dylan Sing   Western Mich.  Sr.   M   21.0      7.0
# 20  NaN    Johann von Knebel   New Hampshire  Sr.   M   20.0      7.0
# 21  NaN           Reed Berry    Oral Roberts  Sr.   M   17.0      6.0
# 22  NaN           Tim Bielic       Wisconsin  Sr.   M   16.0      6.0
# 23  NaN      Yusuf Cueceoglu           UTRGV  Sr.   M   17.0      6.0
# 24  NaN         Hector Gomez   Cleveland St.  Sr.   M   20.0      6.0
# 25  NaN      Parker McKnight      Binghamton  Sr.   M   17.0      6.0
# 26  NaN          Yushi Nagao             FIU  Sr.   M   19.0      6.0
# 27  NaN           Lucas Rosa      Pittsburgh  Sr.   M   22.0      6.0
# 28  NaN        Gurman Sangha        Portland  Sr.   M   21.0      6.0
# 29  NaN          Kyle Tucker          Drexel  Sr.   M   18.0      6.0
# 30  NaN      Lane Warrington     Saint Louis  Sr.   M   20.0      6.0
# 31  NaN        Callum Watson       Creighton  Sr.   M   22.0      6.0
# 32  NaN        Jansen Wilson         Belmont  Sr.   M   18.0      6.0

# %%
SELECT * FROM table_ncaa_d1_ttla WHERE Cl = 'Sr.' AND Pos = 'F'
# Out:
#    Rank                  Name                Team   Cl Pos  Games  Assists
# 0     4           Tom Cooklin   George Washington  Sr.   F   17.0     13.0
# 1     7          Eric Conerty       Western Mich.  Sr.   F   21.0     11.0
# 2   NaN      Ryan Wittenbrink             Indiana  Sr.   F   24.0      9.0
# 3    28          Marco Afonso      UNC Greensboro  Sr.   F   21.0      8.0
# 4   NaN        Sergi Martinez       Bowling Green  Sr.   F   16.0      8.0
# 5    53           Brage Aasen          Quinnipiac  Sr.   F   12.0      7.0
# 6   NaN         David Bercedo          Quinnipiac  Sr.   F   21.0      7.0
# 7   NaN           Emeka Eneli             Cornell  Sr.   F   17.0      7.0
# 8   NaN      Daniel Hernandez            Campbell  Sr.   F   20.0      7.0
# 9   NaN         Bryan Iliohan  California Baptist  Sr.   F   21.0      7.0
# 10  NaN      Demitrius Kigeya             Gonzaga  Sr.   F   18.0      7.0
# 11  NaN         Kameron Lacey           Charlotte  Sr.   F   16.0      7.0
# 12  NaN        Mike Melaragni       Western Mich.  Sr.   F   20.0      7.0
# 13  NaN              MD Myers             Rutgers  Sr.   F   21.0      7.0
# 14  NaN           Diba Nwegbo      William & Mary  Sr.   F   17.0      7.0
# 15  NaN  Sebastian Andreassen        Central Ark.  Sr.   F   16.0      6.0
# 16  NaN       Mike Eijgendaal              Temple  Sr.   F   16.0      6.0
# 17  NaN       Herbert Endeley             Indiana  Sr.   F   24.0      6.0
# 18  NaN           Shaun Joash        Grand Canyon  Sr.   F   16.0      6.0
# 19  NaN       Levonte Johnson            Syracuse  Sr.   F   25.0      6.0
# 20  NaN       Alejandro Lopez            Lipscomb  Sr.   F   18.0      6.0
# 21  NaN          Andrew Nunez        Oral Roberts  Sr.   F   17.0      6.0
# 22  NaN         Chris Pinkham       New Hampshire  Sr.   F   19.0      6.0
# 23  NaN         Dawsun Schrum             Oakland  Sr.   F   18.0      6.0
# 24  NaN          Mohamed Seye             Clemson  Sr.   F   21.0      6.0

# %%
SELECT * FROM table_ncaa_d1_ttla WHERE Cl = 'Sr.' AND Pos = 'D'
# Out:
#   Rank             Name           Team   Cl Pos  Games  Assists
# 0  NaN      Noah Gulden       Lipscomb  Sr.   D   19.0     10.0
# 1  NaN   Connor Drought        Cornell  Sr.   D   18.0      8.0
# 2  NaN    Nathan Simeon  San Francisco  Sr.   D   17.0      8.0
# 3  NaN  Hayden Anderson        Memphis  Sr.   D   19.0      7.0
# 4  NaN    Brendan Clark   UC Riverside  Sr.   D   20.0      7.0
# 5  NaN    Matt Lockwood  Western Mich.  Sr.   D   21.0      7.0
# 6  NaN      Nyk Sessock        Indiana  Sr.   D   24.0      7.0
# 7  NaN    Keegan Tingey       Stanford  Sr.   D   20.0      7.0
# 8  NaN        Omar Grey     Washington  Sr.   D   18.0      6.0
# 9  NaN      Kasper Lehm           Elon  Sr.   D   16.0      6.0

# %%
SELECT Pos, COUNT(*) FROM table_ncaa_d1_apg WHERE Cl = 'Sr.' GROUP BY Pos
# Out:
#   Pos  count_star()
# 0   M            34
# 1   F            23
# 2   D             9

# %%
SELECT * FROM table_ncaa_d1_apg WHERE Cl = 'Sr.' AND Pos = 'M'
# Out:
#    Rank                 Name            Team   Cl Pos  Games  Assists  Per Game
# 0     1         Nick Gutmann        Kentucky  Sr.   M   21.0     19.0      0.90
# 1    11          Ryan Becher            UMBC  Sr.   M   18.0     10.0      0.56
# 2   NaN            Alex Nagy         Vermont  Sr.   M   17.0      9.0      0.53
# 3    15        Dylan Gaither          Mercer  Sr.   M   19.0     10.0      0.53
# 4   NaN            Koby Carr       Charlotte  Sr.   M   14.0      7.0      0.50
# 5    28      Jacob Angeletti       Air Force  Sr.   M   17.0      8.0      0.47
# 6   NaN     Malcolm Johnston        Maryland  Sr.   M   17.0      8.0      0.47
# 7   NaN        Stephen Hasse         Niagara  Sr.   M   20.0      9.0      0.45
# 8   NaN   Leopoldo Hernandez    UC Riverside  Sr.   M   20.0      9.0      0.45
# 9   NaN  Alexander Levengood  William & Mary  Sr.   M   18.0      8.0      0.44
# 10  NaN            Ben Stitz            Penn  Sr.   M   18.0      8.0      0.44
# 11  NaN           Louis Sala    Michigan St.  Sr.   M   16.0      7.0      0.44
# 12   53      Brandon Morales         Cornell  Sr.   M   19.0      8.0      0.42
# 13  NaN           Lucas Meek      Washington  Sr.   M   20.0      8.0      0.40
# 14  NaN      Nick Richardson        Maryland  Sr.   M   20.0      8.0      0.40
# 15  NaN      Will Echeverria       Lafayette  Sr.   M   18.0      7.0      0.39
# 16  NaN          Billy Hency  Loyola Chicago  Sr.   M   18.0      7.0      0.39
# 17   76  Mauricio Villalobos             UCF  Sr.   M   13.0      5.0      0.38
# 18  NaN        Charlie Sharp   Western Mich.  Sr.   M   21.0      8.0      0.38
# 19  NaN       Jackson Temple         Rutgers  Sr.   M   21.0      8.0      0.38
# 20  NaN           Tim Bielic       Wisconsin  Sr.   M   16.0      6.0      0.38
# 21   94          Mateo Godoy       Princeton  Sr.   M   14.0      5.0      0.36
# 22   95           Reed Berry    Oral Roberts  Sr.   M   17.0      6.0      0.35
# 23  NaN      Yusuf Cueceoglu           UTRGV  Sr.   M   17.0      6.0      0.35
# 24  NaN      Parker McKnight      Binghamton  Sr.   M   17.0      6.0      0.35
# 25  NaN    Johann von Knebel   New Hampshire  Sr.   M   20.0      7.0      0.35
# 26  NaN   Vinicius Fernandes        Marshall  Sr.   M   15.0      5.0      0.33
# 27  NaN           Dylan Sing   Western Mich.  Sr.   M   21.0      7.0      0.33
# 28  NaN          Kyle Tucker          Drexel  Sr.   M   18.0      6.0      0.33
# 29  NaN        Jansen Wilson         Belmont  Sr.   M   18.0      6.0      0.33
# 30  NaN          Yushi Nagao             FIU  Sr.   M   19.0      6.0      0.32
# 31  NaN           Dylan Lane          Furman  Sr.   M   16.0      5.0      0.31
# 32  NaN       Jacob Schulman          Marist  Sr.   M   16.0      5.0      0.31
# 33   NR     Alessandro Negri       Merrimack  Sr.   M   14.0      5.0      0.36

# %%
SELECT * FROM table_ncaa_d1_apg WHERE Cl = 'Sr.' AND Pos = 'F'
# Out:
#    Rank                  Name                Team  ... Games Assists  Per Game
# 0     2           Tom Cooklin   George Washington  ...  17.0    13.0      0.76
# 1    18          Eric Conerty       Western Mich.  ...  21.0    11.0      0.52
# 2   NaN        Sergi Martinez       Bowling Green  ...  16.0     8.0      0.50
# 3   NaN             Gino Vivi                 UCF  ...  10.0     5.0      0.50
# 4   NaN         Kameron Lacey           Charlotte  ...  16.0     7.0      0.44
# 5   NaN           Emeka Eneli             Cornell  ...  17.0     7.0      0.41
# 6   NaN           Diba Nwegbo      William & Mary  ...  17.0     7.0      0.41
# 7   NaN      Demitrius Kigeya             Gonzaga  ...  18.0     7.0      0.39
# 8    77          Marco Afonso      UNC Greensboro  ...  21.0     8.0      0.38
# 9    80  Sebastian Andreassen        Central Ark.  ...  16.0     6.0      0.38
# 10  NaN       Mike Eijgendaal              Temple  ...  16.0     6.0      0.38
# 11  NaN           Shaun Joash        Grand Canyon  ...  16.0     6.0      0.38
# 12  NaN      Ryan Wittenbrink             Indiana  ...  24.0     9.0      0.38
# 13  NaN          Andrew Nunez        Oral Roberts  ...  17.0     6.0      0.35
# 14  NaN      Daniel Hernandez            Campbell  ...  20.0     7.0      0.35
# 15  NaN        Mike Melaragni       Western Mich.  ...  20.0     7.0      0.35
# 16  NaN         David Bercedo          Quinnipiac  ...  21.0     7.0      0.33
# 17  NaN         Bryan Iliohan  California Baptist  ...  21.0     7.0      0.33
# 18  NaN       Alejandro Lopez            Lipscomb  ...  18.0     6.0      0.33
# 19  NaN              MD Myers             Rutgers  ...  21.0     7.0      0.33
# 20  NaN         Dawsun Schrum             Oakland  ...  18.0     6.0      0.33
# 21  NaN         Chris Pinkham       New Hampshire  ...  19.0     6.0      0.32
# 22  NaN         Ibrahima Diop            Marshall  ...  16.0     5.0      0.31
#
# [23 rows x 8 columns]

# %%
SELECT * FROM table_ncaa_d1_apg WHERE Cl = 'Sr.' AND Pos = 'D'
# Out:
#   Rank             Name           Team   Cl Pos  Games  Assists  Per Game
# 0  NaN      Noah Gulden       Lipscomb  Sr.   D   19.0     10.0      0.53
# 1  NaN    Nathan Simeon  San Francisco  Sr.   D   17.0      8.0      0.47
# 2   41   Connor Drought        Cornell  Sr.   D   18.0      8.0      0.44
# 3  NaN      Kasper Lehm           Elon  Sr.   D   16.0      6.0      0.38
# 4   89  Hayden Anderson        Memphis  Sr.   D   19.0      7.0      0.37
# 5  101    Brendan Clark   UC Riverside  Sr.   D   20.0      7.0      0.35
# 6  NaN    Keegan Tingey       Stanford  Sr.   D   20.0      7.0      0.35
# 7  NaN        Omar Grey     Washington  Sr.   D   18.0      6.0      0.33
# 8  NaN    Matt Lockwood  Western Mich.  Sr.   D   21.0      7.0      0.33

# %%
SELECT Pos, COUNT(*) FROM table_ncaa_d1_glsagt WHERE Cl = 'Sr.' GROUP BY Pos
# Out:
#   Pos  count_star()
# 0  GK            71
# 1   -             1

# %%
SELECT * FROM table_ncaa_d1_glsagt WHERE Cl = 'Sr.' AND Pos != 'GK'
# Out:
#   Rank           Name   Team   Cl Pos  Games Goalie Min. Plyd    GA    GAA
# 0  NaN  Michael Stone  UConn  Sr.   -   11.0           990:00  14.0  1.273

# %%
# Clean up Goals Against Table: Check on Pos '-' and fill in as 'GK' in dataframe
#####

# %%
SELECT Pos, COUNT(*) FROM table_ncaa_d1_gpg WHERE Cl = 'Sr.' GROUP BY Pos
# Out:
#   Pos  count_star()
# 0   F            50
# 1   M            20
# 2   D             4

# %%
SELECT * FROM table_ncaa_d1_gpg WHERE Cl = 'Sr.' AND Pos = 'F'
# Out:
#    Rank                  Name               Team  ... Games Goals  Per Game
# 0     5           Shaun Joash       Grand Canyon  ...  16.0  12.0      0.75
# 1   NaN    Stefan Sigurdarson     Boston College  ...  16.0  12.0      0.75
# 2     9         David Bercedo         Quinnipiac  ...  21.0  14.0      0.67
# 3    12  Finn Ballard McBride   UC Santa Barbara  ...  20.0  13.0      0.65
# 4   NaN     Jelldrik Dallmann           Lipscomb  ...  17.0  11.0      0.65
# 5    18              MD Myers            Rutgers  ...  21.0  13.0      0.62
# 6    24         Kameron Lacey          Charlotte  ...  16.0   9.0      0.56
# 7    26            Liam Butts           Penn St.  ...  13.0   7.0      0.54
# 8    27         Paolo Carroll               Yale  ...  15.0   8.0      0.53
# 9    32        Stephen Afrifa                FIU  ...  19.0  10.0      0.53
# 10  NaN   Eythor Bjorgolfsson           Kentucky  ...  19.0  10.0      0.53
# 11  NaN           Noah Holmes         High Point  ...  21.0  11.0      0.52
# 12   41      Patrick Agyemang       Rhode Island  ...  14.0   7.0      0.50
# 13  NaN       Rodrigo Almeida            Niagara  ...  20.0  10.0      0.50
# 14  NaN  Sebastian Andreassen       Central Ark.  ...  16.0   8.0      0.50
# 15  NaN      Ismail El Harchi     UNC Greensboro  ...  20.0  10.0      0.50
# 16  NaN      Bryant Farkarlun  Houston Christian  ...  18.0   9.0      0.50
# 17  NaN       Nicolo Mulatero       Missouri St.  ...  18.0   9.0      0.50
# 18  NaN           Jack Sarkos             Lehigh  ...  16.0   8.0      0.50
# 19  NaN         Owen Zaldivar       Gardner-Webb  ...  14.0   7.0      0.50
# 20  NaN         Tomas Svecula         Quinnipiac  ...  21.0  10.0      0.48
# 21  NaN           Jalen James           Campbell  ...  17.0   8.0      0.47
# 22  NaN            Milo Yosef           Marshall  ...  17.0   8.0      0.47
# 23  NaN         Fahmi Ibrahim         California  ...  15.0   7.0      0.47
# 24  NaN          Ben Zakowski           Monmouth  ...  15.0   7.0      0.47
# 25   68      Camil Azzam Ruiz               Iona  ...  13.0   6.0      0.46
# 26  NaN   Marcos Kitromilides          Lafayette  ...  18.0   8.0      0.44
# 27   74       Levonte Johnson           Syracuse  ...  25.0  11.0      0.44
# 28  NaN    Oscar Haynes Brown  George Washington  ...  16.0   7.0      0.44
# 29  NaN           Max Wilkins        Georgia St.  ...  16.0   7.0      0.44
# 30   84           David Alino          Dartmouth  ...  14.0   6.0      0.43
# 31  NaN            Hayes Wood           Lipscomb  ...  19.0   8.0      0.42
# 32   92      Ryan Wittenbrink            Indiana  ...  24.0  10.0      0.42
# 33   93         Forster Ajago             Dayton  ...  17.0   7.0      0.41
# 34  NaN            Adam Davie           LMU (CA)  ...  18.0   7.0      0.39
# 35  NaN           Mason Duval               Elon  ...  18.0   7.0      0.39
# 36  NaN          Michael Ille             Mercer  ...  18.0   7.0      0.39
# 37  NaN        Lukas Sunesson          Marquette  ...  18.0   7.0      0.39
# 38  116          Marco Afonso     UNC Greensboro  ...  21.0   8.0      0.38
# 39  NaN          Sam Robinson       Northern Ky.  ...  16.0   6.0      0.38
# 40  NaN          Borna Miklic       UMass Lowell  ...  14.0   5.0      0.36
# 41  NaN          Sam Thornton              Drake  ...  14.0   5.0      0.36
# 42  NaN           Alex Willis          Charlotte  ...  14.0   5.0      0.36
# 43  NaN       Omari Cotterell           La Salle  ...  17.0   6.0      0.35
# 44  NaN             Manny Day             Dayton  ...  17.0   6.0      0.35
# 45  NaN            Aedon Kyra               FGCU  ...  17.0   6.0      0.35
# 46  NaN         Martin Vician            Harvard  ...  17.0   6.0      0.35
# 47   NR     Juri  Schlingmann          Merrimack  ...  17.0  10.0      0.59
# 48   NR       Felipe Mendonca        Queens (NC)  ...  13.0   7.0      0.54
# 49   NR       Johan Feilscher          Merrimack  ...  17.0   7.0      0.41
#
# [50 rows x 8 columns]

# %%
SELECT * FROM table_ncaa_d1_gpg WHERE Cl = 'Sr.' AND Pos = 'M'
# Out:
#    Rank              Name               Team   Cl Pos  Games  Goals  Per Game
# 0     7       Ryan Becher               UMBC  Sr.   M   18.0   13.0      0.72
# 1     8     Knut Ahlander                SMU  Sr.   M   17.0   12.0      0.71
# 2   NaN   Kieran Richards               ETSU  Sr.   M   17.0   11.0      0.65
# 3   NaN         Ben Stitz               Penn  Sr.   M   18.0   11.0      0.61
# 4   NaN         Alex Nagy            Vermont  Sr.   M   17.0    9.0      0.53
# 5   NaN     Valentin Noel         Pittsburgh  Sr.   M   21.0   11.0      0.52
# 6   NaN     Charlie Sharp      Western Mich.  Sr.   M   21.0   11.0      0.52
# 7   NaN        Lucas Meek         Washington  Sr.   M   20.0   10.0      0.50
# 8    65        Davi Alves               FGCU  Sr.   M   15.0    7.0      0.47
# 9   NaN     Pablo Kawecki      Cleveland St.  Sr.   M   20.0    9.0      0.45
# 10  NaN   Brandon Morales            Cornell  Sr.   M   19.0    8.0      0.42
# 11  NaN       Conor Kelly           NC State  Sr.   M   17.0    7.0      0.41
# 12  NaN    Antek Sienkiel    St. John's (NY)  Sr.   M   17.0    7.0      0.41
# 13  NaN   Marko Mitrevski            Liberty  Sr.   M   15.0    6.0      0.40
# 14  NaN       Billy Hency     Loyola Chicago  Sr.   M   18.0    7.0      0.39
# 15  NaN     Kazuki Kimura        Kansas City  Sr.   M   16.0    6.0      0.38
# 16  NaN      Elias Norris  George Washington  Sr.   M   19.0    7.0      0.37
# 17  NaN        Joao Souza           Marshall  Sr.   M   19.0    7.0      0.37
# 18  NaN       Oscar Dueso     Loyola Chicago  Sr.   M   17.0    6.0      0.35
# 19  NaN  Malcolm Johnston           Maryland  Sr.   M   17.0    6.0      0.35

# %%
SELECT * FROM table_ncaa_d1_gpg WHERE Cl = 'Sr.' AND Pos = 'D'
# Out:
#   Rank           Name           Team   Cl Pos  Games  Goals  Per Game
# 0   76     Ryan Clare      Princeton  Sr.   D   16.0    7.0      0.44
# 1  NaN  Daniel Nimick  Western Mich.  Sr.   D   21.0    8.0      0.38
# 2  NaN  Timo Hummrich        Fordham  Sr.   D   16.0    6.0      0.38
# 3  139    Lewis Green   Missouri St.  Sr.   D   14.0    5.0      0.36

# %%
SELECT Pos, COUNT(*) FROM table_ncaa_d1_spg WHERE Cl = 'Sr.' GROUP BY Pos
# Out:
#   Pos  count_star()
# 0  GK            69

# %%
SELECT * FROM table_ncaa_d1_spg WHERE Cl = 'Sr.'
# Out:
#    Rank               Name          Team  ... Goalie Min. Plyd Saves  Per Game
# 0     4      Jacob Heihsel  UMass Lowell  ...          1080:00  68.0      5.67
# 1     5       Gabe Calhoun           VMI  ...          1350:00  84.0      5.60
# 2     9      Joseba Incera       Radford  ...           990:00  60.0      5.45
# 3    10     William Howard      Canisius  ...          1530:00  90.0      5.29
# 4    14   Christian Garner  Northwestern  ...          1170:00  64.0      4.92
# ..  ...                ...           ...  ...              ...   ...       ...
# 64  NaN     Russell Shealy      Syracuse  ...          2220:00  72.0      3.00
# 65  NaN   Alexandre Durand      Longwood  ...          1291:56  47.0      2.94
# 66  150      Carlos Tofern   Saint Louis  ...          1545:00  49.0      2.88
# 67   NR     Dominic Peters  UC San Diego  ...          1395:00  60.0      3.53
# 68   NR  Matthew Brozovich    Bellarmine  ...          1390:00  49.0      3.27
#
# [69 rows x 9 columns]
